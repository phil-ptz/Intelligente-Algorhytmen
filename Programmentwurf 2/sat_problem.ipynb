# %%
import random
import copy

# %% [markdown]
# Konstanten

# %%
n = 2000 # mind. 20
anzahl_individuen = 100 # mind. 100
max_literals = 3 # mind. 3

# %% [markdown]
# Individuen erstellen

# %%
def create(n: int, max_literals: int, anzahl_individuen: int) -> list[list[list[int]]]:
    """ Erstellt Individuen

    Gibt Belegungen einer zufälligen aussagenlogischen Formel als KNF

    ### Args:
    n (int): Anzahl der Aussagenvariablen xn
    max_literals (int): Anzahl der maximalen Literale pro Klausel
    anzahl_individuen (int): Anzahl der zurückgegebenen Individuen

    ### Returns:
    list[list[list[int]]]: Liste von zufälligen Belegungen der Formel

    """

    # Unbelegte Formel als Vorlage für die Individuen erstellen
    formel: list = []
    
    while True:

        if n <= 0:
            break

        k: int = random.randint(1, max_literals)

        if k > n: k = n

        klausel: list = [0 for _ in range(k)]

        formel.append(klausel)

        n -= k


    # Belegungen erstellen
    belegungen: list = []
    rand_literal = lambda : 1 if random.random() < 0.5 else -1

    for _ in range(anzahl_individuen):

        belegung = copy.deepcopy(formel)

        for klausel in belegung:

            for i in range(len(klausel)):

                klausel[i] = rand_literal()

        belegungen.append(belegung)


    # Liste von verschiedenen Belegungen zurückgeben
    return belegungen, formel

# %%
def create_with_shape(shape, anzahl_individuen):

    formel = shape

    # Belegungen erstellen
    belegungen: list = []
    rand_literal = lambda : 1 if random.random() < 0.5 else -1

    for _ in range(anzahl_individuen):

        belegung = copy.deepcopy(formel)

        for klausel in belegung:

            for i in range(len(klausel)):

                klausel[i] = rand_literal()

        belegungen.append(belegung)


    # Liste von verschiedenen Belegungen zurückgeben
    return belegungen

# %%
def check_true(individual: list[list[int]]) -> bool:
    """Gibt den Wahrheitswert einer Belegung zurück"""

    for klausel in individual:

        for literal in klausel:

            if literal == 1:
                break

        else:
            return False
        
    return True

# %%
def num_true_klausel(individual: list[list[int]]) -> int:
    """Gibt die Anzahl der Wahren Klauseln einer Belegung zurück"""

    num: int = 0

    for klausel in individual:

        for literal in klausel:

            if literal == 1:
                break
        else:
            continue

        num += 1
        
    return num

# %%
def get_result(individuals: list[list[list[int]]]) -> str:
    """Gibt das Ergebnis als String zurück"""

    gesamt = 0
    for i in range(len(individuals)):
        gesamt += num_true_klausel(individuals[i])

    return f"Durchschnitt: {gesamt/len(individuals)} Maximal: {len(individuals[0])}"

# %%
def select(individuals, num: int, shape):

    # Alte Selektion (funktioniert nicht so gut)
    """
    sorted_individuals = sorted(individuals, key=num_true_klausel, reverse=True)

    return sorted_individuals[:num] + create_with_shape(shape, len(individuals)-num)"
    """

    # gibt die besten individuen + zufällige individuen zurück 
    selected = sorted(individuals, key=num_true_klausel, reverse=True)[:num]
    remaining = random.choices(individuals, k=len(individuals) - num)
    return selected + remaining

# %%
def mutate(individual: list[list[int]], mutation_rate: float) -> list[list[int]]:
    """Mutiert Belegung nach einer Mutationsrate"""

    mutated = copy.deepcopy(individual)

    for klausel in mutated:

        for i in range(len(klausel)):

            if random.random() < mutation_rate:

                if klausel[i] == 1:
                    klausel[i] = -1
                else:
                    klausel[i] = 1
    
    return mutated

# %%
def rekombiniere(individual1: list[list[int]], individual2: list[list[int]]) -> tuple[list[list[int]],list[list[int]]]:
    """Rekombiniert zwei Belegungen zufällig"""

    child1 = []
    child2 = []

    for i in range(len(individual1)):

        if random.random() < 0.5:

            child1.append(individual1[i])
            child2.append(individual2[i])

        else:

            child1.append(individual2[i])
            child2.append(individual1[i])

    return child1, child2

# %%
population, shape = create(n, max_literals, anzahl_individuen)

# %%
for epoch in range(10000):

    population = select(population, 50, shape)

    for i in range(len(population)):
        population[i] = mutate(population[i], 0.002)

    for i in range(len(population)-1):
        population[i], population[i+1] = rekombiniere(population[i], population[i+1])

    print(f"Epoch: {epoch} \t Result: {get_result(population)}")
    for individual in population:
        if check_true(individual):
            print("Formel ist erfüllbar!")
            break
    else:
        continue
    break
# Out:
# Epoch: 0 	 Result: Durchschnitt: 718.18 Maximal: 1019
# Epoch: 1 	 Result: Durchschnitt: 724.05 Maximal: 1019
# Epoch: 2 	 Result: Durchschnitt: 729.82 Maximal: 1019
# Epoch: 3 	 Result: Durchschnitt: 734.92 Maximal: 1019
# Epoch: 4 	 Result: Durchschnitt: 739.64 Maximal: 1019
# Epoch: 5 	 Result: Durchschnitt: 746.25 Maximal: 1019
# Epoch: 6 	 Result: Durchschnitt: 753.36 Maximal: 1019
# Epoch: 7 	 Result: Durchschnitt: 759.11 Maximal: 1019
# Epoch: 8 	 Result: Durchschnitt: 763.8 Maximal: 1019
# Epoch: 9 	 Result: Durchschnitt: 771.26 Maximal: 1019
# Epoch: 10 	 Result: Durchschnitt: 775.74 Maximal: 1019
# Epoch: 11 	 Result: Durchschnitt: 780.46 Maximal: 1019
# Epoch: 12 	 Result: Durchschnitt: 787.08 Maximal: 1019
# Epoch: 13 	 Result: Durchschnitt: 791.44 Maximal: 1019
# Epoch: 14 	 Result: Durchschnitt: 796.34 Maximal: 1019
# Epoch: 15 	 Result: Durchschnitt: 800.35 Maximal: 1019
# Epoch: 16 	 Result: Durchschnitt: 807.01 Maximal: 1019
# Epoch: 17 	 Result: Durchschnitt: 810.63 Maximal: 1019
# Epoch: 18 	 Result: Durchschnitt: 813.27 Maximal: 1019
# Epoch: 19 	 Result: Durchschnitt: 817.33 Maximal: 1019
# Epoch: 20 	 Result: Durchschnitt: 823.23 Maximal: 1019
# Epoch: 21 	 Result: Durchschnitt: 829.16 Maximal: 1019
# Epoch: 22 	 Result: Durchschnitt: 833.29 Maximal: 1019
# Epoch: 23 	 Result: Durchschnitt: 837.97 Maximal: 1019
# Epoch: 24 	 Result: Durchschnitt: 842.14 Maximal: 1019
# Epoch: 25 	 Result: Durchschnitt: 846.0 Maximal: 1019
# Epoch: 26 	 Result: Durchschnitt: 848.99 Maximal: 1019
# Epoch: 27 	 Result: Durchschnitt: 853.76 Maximal: 1019
# Epoch: 28 	 Result: Durchschnitt: 858.79 Maximal: 1019
# Epoch: 29 	 Result: Durchschnitt: 862.66 Maximal: 1019
# Epoch: 30 	 Result: Durchschnitt: 864.57 Maximal: 1019
# Epoch: 31 	 Result: Durchschnitt: 868.54 Maximal: 1019
# Epoch: 32 	 Result: Durchschnitt: 871.62 Maximal: 1019
# Epoch: 33 	 Result: Durchschnitt: 874.51 Maximal: 1019
# Epoch: 34 	 Result: Durchschnitt: 879.48 Maximal: 1019
# Epoch: 35 	 Result: Durchschnitt: 883.55 Maximal: 1019
# Epoch: 36 	 Result: Durchschnitt: 886.86 Maximal: 1019
# Epoch: 37 	 Result: Durchschnitt: 890.61 Maximal: 1019
# Epoch: 38 	 Result: Durchschnitt: 894.93 Maximal: 1019
# Epoch: 39 	 Result: Durchschnitt: 898.11 Maximal: 1019
# Epoch: 40 	 Result: Durchschnitt: 901.46 Maximal: 1019
# Epoch: 41 	 Result: Durchschnitt: 904.5 Maximal: 1019
# Epoch: 42 	 Result: Durchschnitt: 907.93 Maximal: 1019
# Epoch: 43 	 Result: Durchschnitt: 910.53 Maximal: 1019
# Epoch: 44 	 Result: Durchschnitt: 913.53 Maximal: 1019
# Epoch: 45 	 Result: Durchschnitt: 916.37 Maximal: 1019
# Epoch: 46 	 Result: Durchschnitt: 918.92 Maximal: 1019
# Epoch: 47 	 Result: Durchschnitt: 921.44 Maximal: 1019
# Epoch: 48 	 Result: Durchschnitt: 925.01 Maximal: 1019
# Epoch: 49 	 Result: Durchschnitt: 927.79 Maximal: 1019
# Epoch: 50 	 Result: Durchschnitt: 929.83 Maximal: 1019
# Epoch: 51 	 Result: Durchschnitt: 933.68 Maximal: 1019
# Epoch: 52 	 Result: Durchschnitt: 936.17 Maximal: 1019
# Epoch: 53 	 Result: Durchschnitt: 938.81 Maximal: 1019
# Epoch: 54 	 Result: Durchschnitt: 941.06 Maximal: 1019
# Epoch: 55 	 Result: Durchschnitt: 944.11 Maximal: 1019
# Epoch: 56 	 Result: Durchschnitt: 946.71 Maximal: 1019
# Epoch: 57 	 Result: Durchschnitt: 949.54 Maximal: 1019
# Epoch: 58 	 Result: Durchschnitt: 952.35 Maximal: 1019
# Epoch: 59 	 Result: Durchschnitt: 954.67 Maximal: 1019
# Epoch: 60 	 Result: Durchschnitt: 956.91 Maximal: 1019
# Epoch: 61 	 Result: Durchschnitt: 959.34 Maximal: 1019
# Epoch: 62 	 Result: Durchschnitt: 960.44 Maximal: 1019
# Epoch: 63 	 Result: Durchschnitt: 962.87 Maximal: 1019
# Epoch: 64 	 Result: Durchschnitt: 964.75 Maximal: 1019
# Epoch: 65 	 Result: Durchschnitt: 968.3 Maximal: 1019
# Epoch: 66 	 Result: Durchschnitt: 970.23 Maximal: 1019
# Epoch: 67 	 Result: Durchschnitt: 971.27 Maximal: 1019
# Epoch: 68 	 Result: Durchschnitt: 972.81 Maximal: 1019
# Epoch: 69 	 Result: Durchschnitt: 974.35 Maximal: 1019
# Epoch: 70 	 Result: Durchschnitt: 976.31 Maximal: 1019
# Epoch: 71 	 Result: Durchschnitt: 976.71 Maximal: 1019
# Epoch: 72 	 Result: Durchschnitt: 977.42 Maximal: 1019
# Epoch: 73 	 Result: Durchschnitt: 978.86 Maximal: 1019
# Epoch: 74 	 Result: Durchschnitt: 979.83 Maximal: 1019
# Epoch: 75 	 Result: Durchschnitt: 981.4 Maximal: 1019
# Epoch: 76 	 Result: Durchschnitt: 983.29 Maximal: 1019
# Epoch: 77 	 Result: Durchschnitt: 984.81 Maximal: 1019
# Epoch: 78 	 Result: Durchschnitt: 985.71 Maximal: 1019
# Epoch: 79 	 Result: Durchschnitt: 986.47 Maximal: 1019
# Epoch: 80 	 Result: Durchschnitt: 988.08 Maximal: 1019
# Epoch: 81 	 Result: Durchschnitt: 989.56 Maximal: 1019
# Epoch: 82 	 Result: Durchschnitt: 990.54 Maximal: 1019
# Epoch: 83 	 Result: Durchschnitt: 992.49 Maximal: 1019
# Epoch: 84 	 Result: Durchschnitt: 993.72 Maximal: 1019
# Epoch: 85 	 Result: Durchschnitt: 996.19 Maximal: 1019
# Epoch: 86 	 Result: Durchschnitt: 996.25 Maximal: 1019
# Epoch: 87 	 Result: Durchschnitt: 997.08 Maximal: 1019
# Epoch: 88 	 Result: Durchschnitt: 998.25 Maximal: 1019
# Epoch: 89 	 Result: Durchschnitt: 999.64 Maximal: 1019
# Epoch: 90 	 Result: Durchschnitt: 1000.32 Maximal: 1019
# Epoch: 91 	 Result: Durchschnitt: 1001.02 Maximal: 1019
# Epoch: 92 	 Result: Durchschnitt: 1001.36 Maximal: 1019
# Epoch: 93 	 Result: Durchschnitt: 1002.88 Maximal: 1019
# Epoch: 94 	 Result: Durchschnitt: 1003.02 Maximal: 1019
# Epoch: 95 	 Result: Durchschnitt: 1003.14 Maximal: 1019
# Epoch: 96 	 Result: Durchschnitt: 1003.85 Maximal: 1019
# Epoch: 97 	 Result: Durchschnitt: 1004.1 Maximal: 1019
# Epoch: 98 	 Result: Durchschnitt: 1004.09 Maximal: 1019
# Epoch: 99 	 Result: Durchschnitt: 1004.92 Maximal: 1019
# Epoch: 100 	 Result: Durchschnitt: 1005.3 Maximal: 1019
# Epoch: 101 	 Result: Durchschnitt: 1005.25 Maximal: 1019
# Epoch: 102 	 Result: Durchschnitt: 1004.63 Maximal: 1019
# Epoch: 103 	 Result: Durchschnitt: 1005.05 Maximal: 1019
# Epoch: 104 	 Result: Durchschnitt: 1005.44 Maximal: 1019
# Epoch: 105 	 Result: Durchschnitt: 1006.07 Maximal: 1019
# Epoch: 106 	 Result: Durchschnitt: 1006.21 Maximal: 1019
# Epoch: 107 	 Result: Durchschnitt: 1006.41 Maximal: 1019
# Epoch: 108 	 Result: Durchschnitt: 1006.75 Maximal: 1019
# Epoch: 109 	 Result: Durchschnitt: 1007.21 Maximal: 1019
# Epoch: 110 	 Result: Durchschnitt: 1007.13 Maximal: 1019
# Epoch: 111 	 Result: Durchschnitt: 1006.48 Maximal: 1019
# Epoch: 112 	 Result: Durchschnitt: 1006.41 Maximal: 1019
# Epoch: 113 	 Result: Durchschnitt: 1006.83 Maximal: 1019
# Epoch: 114 	 Result: Durchschnitt: 1006.75 Maximal: 1019
# Epoch: 115 	 Result: Durchschnitt: 1006.73 Maximal: 1019
# Epoch: 116 	 Result: Durchschnitt: 1006.67 Maximal: 1019
# Epoch: 117 	 Result: Durchschnitt: 1006.41 Maximal: 1019
# Epoch: 118 	 Result: Durchschnitt: 1006.99 Maximal: 1019
# Epoch: 119 	 Result: Durchschnitt: 1006.86 Maximal: 1019
# Epoch: 120 	 Result: Durchschnitt: 1007.37 Maximal: 1019
# Epoch: 121 	 Result: Durchschnitt: 1007.38 Maximal: 1019
# Epoch: 122 	 Result: Durchschnitt: 1008.06 Maximal: 1019
# Epoch: 123 	 Result: Durchschnitt: 1008.36 Maximal: 1019
# Epoch: 124 	 Result: Durchschnitt: 1008.38 Maximal: 1019
# Epoch: 125 	 Result: Durchschnitt: 1008.27 Maximal: 1019
# Epoch: 126 	 Result: Durchschnitt: 1009.0 Maximal: 1019
# Epoch: 127 	 Result: Durchschnitt: 1009.43 Maximal: 1019
# Epoch: 128 	 Result: Durchschnitt: 1009.5 Maximal: 1019
# Epoch: 129 	 Result: Durchschnitt: 1009.78 Maximal: 1019
# Epoch: 130 	 Result: Durchschnitt: 1009.92 Maximal: 1019
# Epoch: 131 	 Result: Durchschnitt: 1009.81 Maximal: 1019
# Epoch: 132 	 Result: Durchschnitt: 1009.94 Maximal: 1019
# Epoch: 133 	 Result: Durchschnitt: 1009.68 Maximal: 1019
# Epoch: 134 	 Result: Durchschnitt: 1009.51 Maximal: 1019
# Epoch: 135 	 Result: Durchschnitt: 1009.61 Maximal: 1019
# Formel ist erfüllbar!
